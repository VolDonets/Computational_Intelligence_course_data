# %% [markdown]
# # The basic

# %% [markdown]
# ## The second

# %% [markdown]
# ### The third

# %% [markdown]
# This a plain text.

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 5

# %%
print(a)
# Out:
# 5

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data for x-axis
x = np.linspace(0, 5 * np.pi, 500)  # 100 points between 0 and 2*pi

# Calculate sine and cosine values
y_sin = np.sin(x)
y_cos = np.cos(x)

# Create the plot
plt.figure(figsize=(12, 6))  # Set the figure size

# Plot sine function
plt.plot(x, y_sin, label='sin(x)', color='blue')

# Plot cosine function
plt.plot(x, y_cos, label='cos(x)', color='red')

# Add labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Sine and Cosine Functions')

# Add legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()
